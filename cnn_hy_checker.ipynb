# %% [markdown]
# # CNN Hyperparameter Checker

# %% [markdown]
# This notebook helps check the design of CNN hyperparameters.

# %%
from src.model import CNN

# %% [markdown]
# Modify the model arguments in the following dictionary and run the cell. The decided remaining arguments for CNN will be displayed.

# %%
model_args = {
    "input_window": True,
    "input_window_args": {
        "start_indices": 0,
        "window_size": 3000
    },

    "gated": False,

    "input_size": 3000,
    "input_dim": 1,
    "output_size": 3000,
    "output_dim": 1,
    "kernel_sizes": [7],
    "layer_strides": [1],
    "padding": 0,

    "pooling_type": "average_pool",
    "global_pooling_type": "max_pool",
    "activation": "relu",
    "mlp_head": True,
    "mlp_head_args": {
        "input_window": False,
        "input_window_args": {
            "start_indices": 0,
            "window_size": 256
        },
        "gated": False,

        "input_dim": 256,
        "output_dim": 256,
        "layers": 2,
        "hidden_dims": [300, 300],
        "activation": "relu"
    }
}
model = CNN(model_args)
model_size = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Model size: {model_size} parameters")
model.model_args
# Out:
# Model size: 244466 parameters
# {'input_window': True,
#  'input_window_args': {'start_indices': 0, 'window_size': 3000},
#  'gated': False,
#  'input_size': 3000,
#  'input_dim': 1,
#  'output_size': 3000,
#  'output_dim': 1,
#  'kernel_sizes': [7],
#  'layer_strides': [1],
#  'padding': 0,
#  'pooling_type': 'average_pool',
#  'global_pooling_type': 'max_pool',
#  'activation': 'relu',
#  'mlp_head': True,
#  'mlp_head_args': {'input_window': False,
#   'input_window_args': {'start_indices': 0, 'window_size': 256},
#   'gated': False,
#   'input_dim': 256,
#   'output_dim': 256,
#   'layers': 2,
#   'hidden_dims': [300, 300],
#   'activation': 'relu'},
#  'num_kernels': [1],
#  'pooling_sizes': [1],
#  'layer_sizes': [3000, 2994],
#  'layer_dims': [1, 1]}
